# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !/opt/bin/nvidia-smi
# Out:
# Mon Oct 31 09:25:04 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch
print(torch.__version__)
torch.cuda.is_available()
# Out:
# 1.12.1+cu113
# True

# %%
# !pip install torch==1.7.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.7.0
#   Downloading torch-1.7.0-cp37-cp37m-manylinux1_x86_64.whl (776.7 MB)
#      |████████████████████████████████| 776.7 MB 4.4 kB/s
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0) (4.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0) (1.21.6)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0) (0.16.0)
# Installing collected packages: dataclasses, torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 1.7.0 which is incompatible.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.7.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.7.0 which is incompatible.
# Successfully installed dataclasses-0.6 torch-1.7.0

# %%
# %cd /content/drive/My Drive/New_Bchmk
# Out:
# /content/drive/My Drive/New_Bchmk

# %%
# !ls
# Out:
# drive  sample_data

# %%
import torch
torch.cuda.empty_cache()

# %%
# !python main.py
# Out:
# i have cudaaaa!!
# i have cudaaaa!!
# i have cudaaaa!!
# i have cudaaaa!!
# i have cudaaaa!!
# i have cudaaaa!!
# i have cudaaaa!!
# i have cudaaaa!!
# i have cudaaaa!!
# i have cudaaaa!!
# i have cudaaaa!!
# You can use this benchmark in four different ways:
#  [1] The first is to test 1 model with 1 dataset,
#  [2] The second is to test 1 model with all datasets,
#  [3] The third is to test all models with 1 datasets,
#  [4] The fourth is to test all models with all dataset.
#  Input number 1, 2, 3, 4 to select your preferred approach to use this benchmark
# test 1 model with 1 dataset
# type the model you prefer, ['DKT', 'DKVMN', 'DKTP', 'KQN', 'SAKT', 'SAINT']
# SAKTM
# type the dataset you prefer, ['ass09', 'ass12', 'ass15', 'assch', 'stat', 'junyi10', 'alg05', 'alg06', 'algbg', 'poj']
# ass12
# You are using the model sakt  with the dataset None
# ass12
# ckpts/sakt ass12
# I AM USING  Average_confidence(BORED) and attempt_count and Average_confidence(CONCENTRATING)
# Found existing pkl
# Epoch: 1,   AUC: 0.64336290220503,   Loss Mean: 0.604377269744873
# Epoch: 2,   AUC: 0.6548965670068037,   Loss Mean: 0.5870111584663391
# Epoch: 3,   AUC: 0.6608146496835436,   Loss Mean: 0.5821123719215393
# Epoch: 4,   AUC: 0.6652259924977935,   Loss Mean: 0.579052746295929
# Epoch: 5,   AUC: 0.6666189484215315,   Loss Mean: 0.5759862661361694
# Epoch: 6,   AUC: 0.6689626092134583,   Loss Mean: 0.5731176733970642
# Epoch: 7,   AUC: 0.6695925239852796,   Loss Mean: 0.5703992247581482
# Epoch: 8,   AUC: 0.6694463791405706,   Loss Mean: 0.5684479475021362
# Epoch: 9,   AUC: 0.6691444997722533,   Loss Mean: 0.5659422874450684
# Epoch: 10,   AUC: 0.6679061653727421,   Loss Mean: 0.5634816884994507
# Epoch: 11,   AUC: 0.6696021744998384,   Loss Mean: 0.5620650053024292
# Epoch: 12,   AUC: 0.6680292491048121,   Loss Mean: 0.5592063069343567
# Epoch: 13,   AUC: 0.6672356999691884,   Loss Mean: 0.5570195317268372
# Epoch: 14,   AUC: 0.6672290021829858,   Loss Mean: 0.5544741153717041
# Epoch: 15,   AUC: 0.6658577316064345,   Loss Mean: 0.5519742965698242
# Epoch: 16,   AUC: 0.6624733438297274,   Loss Mean: 0.550093948841095
# Epoch: 17,   AUC: 0.6635449511417679,   Loss Mean: 0.5473185181617737
# Epoch: 18,   AUC: 0.6631426966003794,   Loss Mean: 0.5457013845443726
# Epoch: 19,   AUC: 0.6606997197622211,   Loss Mean: 0.5424029231071472
# Epoch: 20,   AUC: 0.6622129349576296,   Loss Mean: 0.5405715107917786
# Epoch: 21,   AUC: 0.6593604362821539,   Loss Mean: 0.5378618240356445
# ENOUGH!, The best epoch is 0.6696021744998384

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
a = torch.randn((3, 3, 3))
print(a)
siga = torch.sigmoid(a)
print(siga)
# Out:
# tensor([[[ 0.6378,  1.1459, -1.8741],
#          [ 0.2325,  1.1120, -0.7292],
#          [-0.3358,  0.2857,  1.5859]],
#
#         [[-0.3336, -0.3707, -0.5885],
#          [-0.1993, -0.3862, -0.6594],
#          [-0.6598,  0.9044, -0.8464]],
#
#         [[ 0.3101, -0.5176, -0.6849],
#          [-0.7305,  1.4438, -1.2972],
#          [ 1.2754,  1.1676, -0.8896]]])
# tensor([[[0.6543, 0.7588, 0.1331],
#          [0.5579, 0.7525, 0.3254],
#          [0.4168, 0.5709, 0.8300]],
#
#         [[0.4174, 0.4084, 0.3570],
#          [0.4503, 0.4046, 0.3409],
#          [0.3408, 0.7119, 0.3002]],
#
#         [[0.5769, 0.3734, 0.3352],
#          [0.3251, 0.8090, 0.2146],
#          [0.7817, 0.7627, 0.2912]]])
